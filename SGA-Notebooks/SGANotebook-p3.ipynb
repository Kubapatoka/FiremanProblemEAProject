# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from SGA.SGA import *
from SGA.SGAParts import *
from SGA.SGAInstance import *

from ProblemDef import FirefighterProblem
from Displayer import Displayer

# %%
instance = SGAInstance("problems/p3.json",
    populationInitializer= basicPI,
    populationSize = 10000,
    generationsNumber = 80000,
    parentsSelector = rankingParentsSelector,
    crossover = basicCrossover,
    mutationProb = 0.5,
    mutator = neighbourMutator,
    fixer = basicFixer,
    evaluator = basicEvaluator)


firemans = SGA(instance)
# Out:
# /home/jakub/.local/lib/python3.10/site-packages/networkx/readwrite/json_graph/node_link.py:287: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(
# 71
# [2, 3, 17, 19, 22, 24, 29, 35, 42, 57, 62, 68, 70, 78, 90, 91, 93, 97]

# %%
disp = Displayer()
instance.problem.visualize_fire_without_burned(disp, firemans)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
instance = SGAInstance("problems/p3.json",
    populationInitializer= basicPI,
    populationSize = 200,
    generationsNumber = 80,
    parentsSelector = basicParentsSelector,
    crossover = basicCrossover,
    mutationProb = 0.5,
    mutator = basicMutator,
    fixer = basicFixer,
    evaluator = basicEvaluator)

for i in range(2,40):
    instance.problem.num_teams = i
    print("solution for num teams: ", i)
    firemans = SGA(instance)
# Out:
# /home/jakub/.local/lib/python3.10/site-packages/networkx/readwrite/json_graph/node_link.py:287: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(
# solution for num teams:  2
# 97
# [24, 52]
# solution for num teams:  3
# 96
# [69, 84, 88]
# solution for num teams:  4
# 95
# [48, 65, 82, 91]
# solution for num teams:  5
# 94
# [7, 14, 36, 83, 87]
# solution for num teams:  6
# 93
# [6, 14, 76, 93, 95, 96]
# solution for num teams:  7
# 91
# [3, 4, 13, 36, 68, 84, 90]
# solution for num teams:  8
# 90
# [5, 15, 21, 35, 63, 67, 79, 91]
# solution for num teams:  9
# 89
# [4, 5, 8, 17, 27, 39, 58, 78, 91]
# solution for num teams:  10
# 88
# [24, 27, 31, 67, 68, 72, 78, 90, 91, 99]
# solution for num teams:  11
# ...

# %%
disp = Displayer()
instance.problem.visualize_fire_without_burned(disp, firemans)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
instance = SGAInstance("problems/p3.json",
    populationInitializer= basicPI,
    populationSize = 2000,
    generationsNumber = 180,
    parentsSelector = basicParentsSelector,
    crossover = basicCrossover,
    mutationProb = 0.5,
    mutator = basicMutator,
    fixer = basicFixer,
    evaluator = basicEvaluator)


i = 27
instance.problem.num_teams = i
print("solution for num teams: ", i)
firemans = SGA(instance)

disp = Displayer()
instance.problem.visualize_fire(disp, firemans)
# Out:
# /home/jakub/.local/lib/python3.10/site-packages/networkx/readwrite/json_graph/node_link.py:287: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(
# solution for num teams:  27
# 1
# [7, 15, 16, 17, 18, 27, 28, 32, 37, 38, 41, 45, 49, 51, 52, 55, 61, 64, 67, 73, 75, 78, 87, 90, 93, 94, 99]

# %%
from BruteForce import *
problem = FirefighterProblem.load_from_file("problems/p3.json")
BruteForce(problem)
# Out:
# ([(68, 90)], 96)
